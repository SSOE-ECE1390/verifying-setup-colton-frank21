# %% [markdown]
# # <font style="color:black">Lecture 1: Homework Problem</font>
#
# In this first homework set, I want you to make sure that you can use GitHub, MS Code, and OpenCV.
# You should (already to be able to read this document), clone the Github classroom assignment and edit it in VS Code.  In this python notebook, do the following:
#
# * Load an (Grayscale) image  (‘Data/Apollo_11_Launch.jpg’)
# * View image
# * Crop image
# * Edit brightness of image
# * Rotate image
# * Save modified image

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

Apollo_BGR = cv2.imread(os.path.relpath('Data/Apollo_11_Launch.jpg'))
plt.imshow(Apollo_BGR)

Cropped_Apollo = Apollo_BGR[50:650, 400:800]


Matrix = np.ones(Cropped_Apollo.shape, dtype= "uint8") * 75
Brighter_Apollo = cv2.add(Matrix,Cropped_Apollo)


Modified_Apollo = cv2.flip(Brighter_Apollo, -1)

cv2.imwrite('Modified_Apollo.jpg', Modified_Apollo)
# Out:
# True
